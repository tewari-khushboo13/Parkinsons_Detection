# %% [markdown]
# <a href="https://colab.research.google.com/github/tewari-khushboo13/Parkinsons_Detection/blob/main/Parkinson's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('train_data.csv')

# %%
df.head()
# Out:
#    1  1.488  0.000090213    0.9  0.794  2.699   8.334  0.779  4.517  4.609  \
# 0  1  0.728     0.000038  0.353  0.376  1.059   5.864  0.642  2.058  3.180
# 1  1  1.220     0.000074  0.732  0.670  2.196   8.719  0.875  4.347  5.166
# 2  1  2.502     0.000123  1.156  1.634  3.469  13.513  1.273  5.263  8.771
# 3  1  3.509     0.000167  1.715  1.539  5.145   9.112  1.040  3.102  4.927
# 4  1  2.470     0.000126  1.358  1.341  4.075  10.696  1.256  5.262  7.076
#
#    ...  187.576   160   159  0.006064725  0.000416276       0  0.1     0.2  \
# 0  ...  234.505   170   169     0.005181     0.000403   2.247    0   0.000
# 1  ...  211.442  1431  1427     0.006071     0.000474  10.656    1   0.178
# 2  ...  220.230    94    92     0.004910     0.000320   0.000    0   0.000
# 3  ...  225.162   117   114     0.004757     0.000380  18.182    1  13.318
# 4  ...  202.812    74    73     0.005118     0.000187  23.214    0   0.000
#
#    23  1.1
# 0  23    1
# 1  23    1
# 2  23    1
# 3  23    1
# ...

# %%
df.tail()
# Out:
#        1  1.488  0.000090213    0.9  0.794  2.699   8.334  0.779  4.517  \
# 1034  40  5.127     0.000398  2.721  2.510  8.162   9.846  0.965  4.593
# 1035  40  1.757     0.000133  0.808  0.690  2.425   7.571  0.740  2.720
# 1036  40  2.912     0.000226  1.141  1.266  3.423  15.489  1.456  6.433
# 1037  40  3.788     0.000275  1.786  1.484  5.359  15.702  1.367  6.374
# 1038  40  1.809     0.000149  0.680  0.843  2.040   7.881  0.782  2.690
#
#        4.609  ...  187.576  160  159  0.006064725  0.000416276       0  0.1  \
# 1034   6.806  ...  158.591   63   60     0.007766     0.001066  24.194    2
# 1035   3.927  ...  143.797   47   44     0.007561     0.000430  46.053    1
# 1036  10.138  ...  149.641   79   77     0.007767     0.000881  20.000    1
# 1037  11.094  ...  451.366   75   70     0.007257     0.001714  16.667    3
# 1038   4.543  ...  137.546   62   60     0.008211     0.000566  18.182    1
#
#          0.2  23  1.1
# 1034  15.113   1    0
# 1035  25.792   1    0
# ...

# %%
df.columns
# Out:
# Index(['1', '1.488', '0.000090213', '0.9', '0.794', '2.699', '8.334', '0.779',
#        '4.517', '4.609', '6.802', '13.551', '0.905905', '0.119116', '11.13',
#        '166.533', '164.781', '10.421', '142.229', '187.576', '160', '159',
#        '0.006064725', '0.000416276', '0', '0.1', '0.2', '23', '1.1'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('train_data.csv')
X = df.drop('1.1', axis=1)
y = df['1.1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.5, penalty="l1", dual=False, random_state=42).fit(X_train, y_train)
model = SelectFromModel(lsvc, prefit=True)
X_train_new = model.transform(X_train)
X_test_new = model.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.5, penalty="l2", dual=False, random_state=42).fit(X_train, y_train)
model = SelectFromModel(lsvc, prefit=True)
X_train_new = model.transform(X_train)
X_test_new = model.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(units=40, activation='relu', input_dim=X_train_new.shape[1]))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=40, activation='relu'))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train_new, y_train, epochs=100, batch_size=10, verbose=1)
loss, accuracy = model.evaluate(X_test_new, y_test)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 2ms/step - loss: 0.3178 - accuracy: 0.9013
# Epoch 2/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9988
# Epoch 3/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 4/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 5/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 6/100
# 84/84 [==============================] - 0s 2ms/step - loss: 6.4946e-04 - accuracy: 1.0000
# Epoch 7/100
# 84/84 [==============================] - 0s 2ms/step - loss: 4.2350e-04 - accuracy: 1.0000
# Epoch 8/100
# 84/84 [==============================] - 0s 2ms/step - loss: 2.9008e-04 - accuracy: 1.0000
# Epoch 9/100
# 84/84 [==============================] - 0s 2ms/step - loss: 2.2186e-04 - accuracy: 1.0000
# Epoch 10/100
# ...

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.5, penalty="l2", dual=False, random_state=42).fit(X_train, y_train)
model = SelectFromModel(lsvc, prefit=True)
X_train_new = model.transform(X_train)
X_test_new = model.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(units=40, activation='relu', input_dim=X_train_new.shape[1]))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=40, activation='relu'))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train_new, y_train, epochs=100, batch_size=10, verbose=1)
loss, accuracy = model.evaluate(X_test_new, y_test)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 2ms/step - loss: 0.1137 - accuracy: 0.9591
# Epoch 2/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9988
# Epoch 3/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 4/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 5/100
# 84/84 [==============================] - 0s 2ms/step - loss: 3.2221e-04 - accuracy: 1.0000
# Epoch 6/100
# 84/84 [==============================] - 0s 2ms/step - loss: 2.2026e-04 - accuracy: 1.0000
# Epoch 7/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.7312e-04 - accuracy: 1.0000
# Epoch 8/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3121e-04 - accuracy: 1.0000
# Epoch 9/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.2268e-04 - accuracy: 1.0000
# Epoch 10/100
# ...
